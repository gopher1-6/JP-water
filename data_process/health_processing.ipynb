# %% [markdown]
# # 数据处理

# %% [markdown]
# ## 数据处理 - 健康

# %% [markdown]
# NDB_H28.xlsx
#
#
# > 健康数据，NDB
#
# >     col 0	县
# >     col 1	指标，取BMI，腹围，空腹血糖三项，代表了肥胖和糖尿病
# >     col 9	男性平均
# >     col 17	女性平均

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import numpy as np
import pandas as pd
pd.set_option('display.width', 200)   # 每行最大字符
pd.set_option('precision', 3)         # 显示数字精度
pd.set_option('display.max_rows', 25) # 预览时最多显示行数
pd.set_option('display.float_format', lambda x : '%.2f' % x)  # 不使用科学计数法

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.transforms as transforms

plt.rcParams['figure.figsize'] = 18, 9
plt.rcParams['axes.unicode_minus'] = False     # 显示数字负号
plt.rcParams['font.sans-serif'] = ['SimHei']   # 显示中文字体
mpl.rcParams['figure.dpi'] = 80
mpl.rcParams['savefig.dpi'] = 100
mpl.rcParams['font.size'] = 12
mpl.rcParams['legend.fontsize'] = 'large'
mpl.rcParams['figure.titlesize'] = 'medium'
plt.style.use('seaborn-whitegrid')

import seaborn as sns

def explore(df, n=5, describe=False, info=False):
  print('rows x cols:', df.shape)
  print('column name:', '\t'.join(df.columns))
  print()
  if describe:
    print('==== describe ====')
    print(df.describe())
  if info:
    print('==== info ====')
    print(df.info())
  print('==== sample ====')
  return df.sample(n=n, random_state=100)

# explore_df(df)

def find_in(df, col, pat):
  ''' 在 col 中 查找命中 pat 的数据
      如果 pat 是 字符串, 视为模糊查找 
      如果 pat 是 list, 或者非字符串型, 视为精确查找 '''
  if isinstance(pat, str):
    return df[df[col].str.contains(pat)]
  if not isinstance(pat, (list, set)):
    pat = [pat]
  return df[df[col].isin(pat)]

# %% [markdown]
# ### 预览 NDB_H28.xlsx

# %%
health_df = pd.read_excel("../NDB_H28.xlsx", header=1, index_col='都道府県')
health_df.reset_index(inplace=True)

# %%
health_df.head(18)
# Out:
#    都道府県               検査項目      全体 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0   NaN                NaN       男        NaN        NaN        NaN        NaN        NaN        NaN        NaN           女         NaN         NaN         NaN         NaN         NaN         NaN
# 1   NaN                NaN  40～44歳     45～49歳     50～54歳     55～59歳     60～64歳     65～69歳     70～74歳         中計      40～44歳      45～49歳      50～54歳      55～59歳      60～64歳      65～69歳      70～74歳
# 2   NaN                NaN      平均         平均         平均         平均         平均         平均         平均         平均          平均          平均          平均          平均          平均          平均          平均
# 3   北海道          BMI[kg/㎡]   24.39      24.52      24.41      24.28      24.15      23.98      23.82      24.28       22.04       22.31       22.26       22.39       22.65       22.77       22.99
# 4   NaN             腹囲[cm]   84.49      85.33      85.54      85.56      85.54      85.35      84.93      85.24       76.81       77.81       78.22       79.08       80.12       80.51       81.36
# 5   NaN       空腹時血糖[mg/dl]   95.36      98.12     101.15     103.51     105.07     104.86     103.83     100.96       89.24       90.46       91.96       93.95       94.83       95.59       96.27
# 6   NaN     HbA1c（NGSP）[％]    5.46       5.55       5.64       5.72       5.79       5.79       5.77       5.66        5.32        5.38        5.49        5.59        5.63        5.66        5.69
# 7   NaN        収縮期血圧[mmHg]  121.13     123.21     125.53     128.17     130.54     132.46     133.58     126.79      112.43      115.63      118.60      121.39      125.18      128.65      131.32
# 8   NaN        拡張期血圧[mmHg]   75.93      78.19      79.94      80.59      80.04      78.91      77.03      78.67       69.08       70.92       72.74       73.79       74.44       74.89       74.57
# 9   NaN        中性脂肪[mg/dl]  135.33     140.34     142.30     138.24     133.23     127.01     121.26     135.48       78.66       84.12       92.89       98.45      102.74      105.33      105.98
# 10  NaN  ＨＤＬコレステロール[mg/dl]   56.76      57.19      58.09      58.59      58.28      58.24      57.84      57.79       68.94       70.24       72.42       71.66       69.80       68.00       66.55
# 11  NaN  ＬＤＬコレステロール[mg/dl]  126.78     127.46     126.42     123.77     121.66     119.97     116.81     124.16      111.12      117.55      127.71      132.16      131.93      129.89      125.66
# 12  NaN      GOT（AST）[U/l]   24.97      25.33      25.49      25.60      25.79      25.81      25.99      25.50       19.02       19.79       21.86       23.18       23.52       23.83       24.29
# 13  NaN      GPT（ALT）[U/l]   31.19      30.32      28.94      27.59      26.36      24.87      23.29      28.16       16.36       17.22       19.70       21.11       20.82       20.32       19.68
# 14  NaN   γ-GT（γ-GTP）[U/l]   51.00      55.38      58.54      58.36      55.21      49.76      44.80      54.08       22.60       24.70       29.40       31.70       29.78       27.66       25.97
# 15  NaN       ヘモグロビン[g/dl]   15.25      15.20      15.10      14.97      14.81      14.70      14.97      15.10       12.73       12.78       13.26       13.44       13.33       12.98       13.18
# 16  青森県          BMI[kg/㎡]   24.51      24.41      24.23      24.05      23.95      23.81      23.60      24.13       22.36       22.57       22.68       22.69       22.96       23.13       23.29
# 17  NaN             腹囲[cm]   84.44      84.70      84.68      84.48      84.41      84.21      83.82      84.43       77.46       78.26       79.13       79.74       80.73       81.40       82.17
#
#    Unnamed: 17
# 0          NaN
# 1           中計
# 2           平均
# 3        22.47
# 4        79.04
# 5        92.88
# 6         5.54
# 7       121.52
# 8        72.81
# 9        94.91
# 10       69.69
# 11      124.83
# 12       22.10
# 13       19.23
# 14       27.30
# 15       13.05
# 16       22.83
# 17       79.94

# %%
# `中計` `中計.1` 分别是男女平均, 在`Unnamed: 9` `Unnamed: 17` 的位置

health_df = health_df[['都道府県', '検査項目', 'Unnamed: 9', 'Unnamed: 17']]
health_df.columns = ['都道府県', '検査項目', '男性平均', '女性平均']

# %%
health_df.head(25)
# Out:
#    都道府県               検査項目   男性平均   女性平均
# 0   NaN                NaN    NaN    NaN
# 1   NaN                NaN     中計     中計
# 2   NaN                NaN     平均     平均
# 3   北海道          BMI[kg/㎡]  24.28  22.47
# 4   NaN             腹囲[cm]  85.24  79.04
# 5   NaN       空腹時血糖[mg/dl] 100.96  92.88
# 6   NaN     HbA1c（NGSP）[％]   5.66   5.54
# 7   NaN        収縮期血圧[mmHg] 126.79 121.52
# 8   NaN        拡張期血圧[mmHg]  78.67  72.81
# 9   NaN        中性脂肪[mg/dl] 135.48  94.91
# 10  NaN  ＨＤＬコレステロール[mg/dl]  57.79  69.69
# 11  NaN  ＬＤＬコレステロール[mg/dl] 124.16 124.83
# 12  NaN      GOT（AST）[U/l]  25.50  22.10
# 13  NaN      GPT（ALT）[U/l]  28.16  19.23
# 14  NaN   γ-GT（γ-GTP）[U/l]  54.08  27.30
# 15  NaN       ヘモグロビン[g/dl]  15.10  13.05
# 16  青森県          BMI[kg/㎡]  24.13  22.83
# 17  NaN             腹囲[cm]  84.43  79.94
# 18  NaN       空腹時血糖[mg/dl] 104.20  95.67
# 19  NaN     HbA1c（NGSP）[％]   5.73   5.64
# 20  NaN        収縮期血圧[mmHg] 127.10 122.29
# 21  NaN        拡張期血圧[mmHg]  80.26  74.25
# 22  NaN        中性脂肪[mg/dl] 136.13  91.88
# 23  NaN  ＨＤＬコレステロール[mg/dl]  59.23  69.97
# 24  NaN  ＬＤＬコレステロール[mg/dl] 123.78 124.92

# %%
# 从检查项目中, 保留 `BMI[kg/㎡]` `腹囲[cm]` `空腹時血糖[mg/dl]`
# 其余去掉去掉第一行是记录 `平均` 的表头, 去掉

health_df = health_df[health_df.検査項目.isin(['BMI[kg/㎡]', '腹囲[cm]', '空腹時血糖[mg/dl]'])]

# %%
health_df = health_df.reset_index()
health_df.drop(columns=['index'], inplace=True)
health_df
# 总计 144 行, 
# 144 / 3 = 48, 因为最后有一个 "全国"
# Out:
#      都道府県          検査項目   男性平均  女性平均
# 0     北海道     BMI[kg/㎡]  24.28 22.47
# 1     NaN        腹囲[cm]  85.24 79.04
# 2     NaN  空腹時血糖[mg/dl] 100.96 92.88
# 3     青森県     BMI[kg/㎡]  24.13 22.83
# 4     NaN        腹囲[cm]  84.43 79.94
# 5     NaN  空腹時血糖[mg/dl] 104.20 95.67
# 6     岩手県     BMI[kg/㎡]  24.07 22.80
# 7     NaN        腹囲[cm]  84.73 80.70
# 8     NaN  空腹時血糖[mg/dl] 102.76 94.59
# 9     宮城県     BMI[kg/㎡]  24.12 22.59
# 10    NaN        腹囲[cm]  85.46 80.59
# 11    NaN  空腹時血糖[mg/dl] 101.87 93.56
# ..    ...           ...    ...   ...
# 132   宮崎県     BMI[kg/㎡]  23.99 22.62
# 133   NaN        腹囲[cm]  85.02 81.11
# 134   NaN  空腹時血糖[mg/dl] 101.58 93.89
# 135  鹿児島県     BMI[kg/㎡]  24.04 22.71
# 136   NaN        腹囲[cm]  85.05 80.77
# 137   NaN  空腹時血糖[mg/dl] 103.77 95.74
# 138   沖縄県     BMI[kg/㎡]  25.02 23.49
# 139   NaN        腹囲[cm]  87.26 82.32
# 140   NaN  空腹時血糖[mg/dl] 102.91 94.70
# 141    全国     BMI[kg/㎡]  23.89 22.22
# 142   NaN        腹囲[cm]  84.88 79.54
# 143   NaN  空腹時血糖[mg/dl] 100.90 93.49
#
# [144 rows x 4 columns]

# %%
# 去掉 "全国" 的三行
health_df = health_df.drop([141, 142, 143])

# %%
# 将 `都道府県` 重复三次

series = []
for name in health_df.都道府県:
  if isinstance(name, str):
    series.append(name)
  else:
    series.append(series[-1])  # 检测到 NaN 就重复上一次的地名

health_df['都道府県'] = series
health_df
# Out:
#      都道府県          検査項目   男性平均  女性平均
# 0     北海道     BMI[kg/㎡]  24.28 22.47
# 1     北海道        腹囲[cm]  85.24 79.04
# 2     北海道  空腹時血糖[mg/dl] 100.96 92.88
# 3     青森県     BMI[kg/㎡]  24.13 22.83
# 4     青森県        腹囲[cm]  84.43 79.94
# 5     青森県  空腹時血糖[mg/dl] 104.20 95.67
# 6     岩手県     BMI[kg/㎡]  24.07 22.80
# 7     岩手県        腹囲[cm]  84.73 80.70
# 8     岩手県  空腹時血糖[mg/dl] 102.76 94.59
# 9     宮城県     BMI[kg/㎡]  24.12 22.59
# 10    宮城県        腹囲[cm]  85.46 80.59
# 11    宮城県  空腹時血糖[mg/dl] 101.87 93.56
# ..    ...           ...    ...   ...
# 129   大分県     BMI[kg/㎡]  23.98 22.51
# 130   大分県        腹囲[cm]  84.89 80.67
# 131   大分県  空腹時血糖[mg/dl] 101.84 94.30
# 132   宮崎県     BMI[kg/㎡]  23.99 22.62
# 133   宮崎県        腹囲[cm]  85.02 81.11
# 134   宮崎県  空腹時血糖[mg/dl] 101.58 93.89
# 135  鹿児島県     BMI[kg/㎡]  24.04 22.71
# 136  鹿児島県        腹囲[cm]  85.05 80.77
# 137  鹿児島県  空腹時血糖[mg/dl] 103.77 95.74
# 138   沖縄県     BMI[kg/㎡]  25.02 23.49
# 139   沖縄県        腹囲[cm]  87.26 82.32
# 140   沖縄県  空腹時血糖[mg/dl] 102.91 94.70
#
# [141 rows x 4 columns]

# %%
# 将 `BMI[kg/㎡]` `腹囲[cm]` `空腹時血糖[mg/dl]` 转成 6 个 columns

temp1 = health_df[health_df.検査項目 == 'BMI[kg/㎡]'].reset_index()
temp1.rename(columns={'男性平均': 'BMI男性平均', '女性平均': 'BMI女性平均'}, inplace=True)

temp2 = health_df[health_df.検査項目 == '腹囲[cm]'].reset_index()
temp2.rename(columns={'男性平均': '腹围男性平均', '女性平均': '腹围女性平均', '都道府県': '--'}, inplace=True)

temp3 = health_df[health_df.検査項目 == '空腹時血糖[mg/dl]'].reset_index()
temp3.rename(columns={'男性平均': '血糖男性平均', '女性平均': '血糖女性平均', '都道府県': '--'}, inplace=True)

health_df_trans = pd.concat([temp1, temp2, temp3], axis=1)
health_df_trans
# Out:
#     index  都道府県       検査項目 BMI男性平均 BMI女性平均  index    --    検査項目 腹围男性平均 腹围女性平均  index    --          検査項目 血糖男性平均 血糖女性平均
# 0       0   北海道  BMI[kg/㎡]   24.28   22.47      1   北海道  腹囲[cm]  85.24  79.04      2   北海道  空腹時血糖[mg/dl] 100.96  92.88
# 1       3   青森県  BMI[kg/㎡]   24.13   22.83      4   青森県  腹囲[cm]  84.43  79.94      5   青森県  空腹時血糖[mg/dl] 104.20  95.67
# 2       6   岩手県  BMI[kg/㎡]   24.07   22.80      7   岩手県  腹囲[cm]  84.73  80.70      8   岩手県  空腹時血糖[mg/dl] 102.76  94.59
# 3       9   宮城県  BMI[kg/㎡]   24.12   22.59     10   宮城県  腹囲[cm]  85.46  80.59     11   宮城県  空腹時血糖[mg/dl] 101.87  93.56
# 4      12   秋田県  BMI[kg/㎡]   24.09   22.76     13   秋田県  腹囲[cm]  85.07  80.27     14   秋田県  空腹時血糖[mg/dl] 103.78  95.41
# 5      15   山形県  BMI[kg/㎡]   23.84   22.58     16   山形県  腹囲[cm]  84.39  79.79     17   山形県  空腹時血糖[mg/dl] 100.91  93.74
# 6      18   福島県  BMI[kg/㎡]   24.10   22.82     19   福島県  腹囲[cm]  85.25  80.72     20   福島県  空腹時血糖[mg/dl] 102.69  95.57
# 7      21   茨城県  BMI[kg/㎡]   24.04   22.53     22   茨城県  腹囲[cm]  85.05  80.09     23   茨城県  空腹時血糖[mg/dl] 102.88  94.77
# 8      24   栃木県  BMI[kg/㎡]   23.98   22.53     25   栃木県  腹囲[cm]  85.04  80.05     26   栃木県  空腹時血糖[mg/dl] 100.38  93.86
# 9      27   群馬県  BMI[kg/㎡]   23.83   22.46     28   群馬県  腹囲[cm]  84.74  79.92     29   群馬県  空腹時血糖[mg/dl] 100.97  94.47
# 10     30   埼玉県  BMI[kg/㎡]   23.92   22.31     31   埼玉県  腹囲[cm]  84.82  79.56     32   埼玉県  空腹時血糖[mg/dl] 100.44  93.42
# 11     33   千葉県  BMI[kg/㎡]   24.04   22.28     34   千葉県  腹囲[cm]  85.27  79.80     35   千葉県  空腹時血糖[mg/dl] 100.54  93.06
# ..    ...   ...        ...     ...     ...    ...   ...     ...    ...    ...    ...   ...           ...    ...    ...
# 35    105   徳島県  BMI[kg/㎡]   24.13   22.59    106   徳島県  腹囲[cm]  85.46  79.91    107   徳島県  空腹時血糖[mg/dl] 101.51  93.94
# 36    108   香川県  BMI[kg/㎡]   23.98   22.47    109   香川県  腹囲[cm]  85.15  79.70    110   香川県  空腹時血糖[mg/dl] 102.37  95.39
# 37    111   愛媛県  BMI[kg/㎡]   24.05   22.44    112   愛媛県  腹囲[cm]  84.86  79.54    113   愛媛県  空腹時血糖[mg/dl] 101.31  92.56
# 38    114   高知県  BMI[kg/㎡]   23.98   22.51    115   高知県  腹囲[cm]  85.29  80.48    116   高知県  空腹時血糖[mg/dl] 104.22  96.11
# 39    117   福岡県  BMI[kg/㎡]   23.85   22.11    118   福岡県  腹囲[cm]  85.09  80.07    119   福岡県  空腹時血糖[mg/dl] 101.97  93.93
# 40    120   佐賀県  BMI[kg/㎡]   23.74   22.36    121   佐賀県  腹囲[cm]  84.93  80.66    122   佐賀県  空腹時血糖[mg/dl] 101.21  93.00
# 41    123   長崎県  BMI[kg/㎡]   23.90   22.47    124   長崎県  腹囲[cm]  84.88  80.32    125   長崎県  空腹時血糖[mg/dl] 101.92  94.32
# 42    126   熊本県  BMI[kg/㎡]   23.95   22.38    127   熊本県  腹囲[cm]  85.36  80.77    128   熊本県  空腹時血糖[mg/dl] 103.24  95.11
# 43    129   大分県  BMI[kg/㎡]   23.98   22.51    130   大分県  腹囲[cm]  84.89  80.67    131   大分県  空腹時血糖[mg/dl] 101.84  94.30
# 44    132   宮崎県  BMI[kg/㎡]   23.99   22.62    133   宮崎県  腹囲[cm]  85.02  81.11    134   宮崎県  空腹時血糖[mg/dl] 101.58  93.89
# 45    135  鹿児島県  BMI[kg/㎡]   24.04   22.71    136  鹿児島県  腹囲[cm]  85.05  80.77    137  鹿児島県  空腹時血糖[mg/dl] 103.77  95.74
# 46    138   沖縄県  BMI[kg/㎡]   25.02   23.49    139   沖縄県  腹囲[cm]  87.26  82.32    140   沖縄県  空腹時血糖[mg/dl] 102.91  94.70
#
# [47 rows x 15 columns]

# %%
# 保留有用的列

columns = ['都道府県', 'BMI男性平均', 'BMI女性平均', '腹围男性平均', '腹围女性平均', '血糖男性平均', '血糖女性平均']
health_df_trans = health_df_trans[columns]
health_df_trans
# Out:
#     都道府県 BMI男性平均 BMI女性平均 腹围男性平均 腹围女性平均 血糖男性平均 血糖女性平均
# 0    北海道   24.28   22.47  85.24  79.04 100.96  92.88
# 1    青森県   24.13   22.83  84.43  79.94 104.20  95.67
# 2    岩手県   24.07   22.80  84.73  80.70 102.76  94.59
# 3    宮城県   24.12   22.59  85.46  80.59 101.87  93.56
# 4    秋田県   24.09   22.76  85.07  80.27 103.78  95.41
# 5    山形県   23.84   22.58  84.39  79.79 100.91  93.74
# 6    福島県   24.10   22.82  85.25  80.72 102.69  95.57
# 7    茨城県   24.04   22.53  85.05  80.09 102.88  94.77
# 8    栃木県   23.98   22.53  85.04  80.05 100.38  93.86
# 9    群馬県   23.83   22.46  84.74  79.92 100.97  94.47
# 10   埼玉県   23.92   22.31  84.82  79.56 100.44  93.42
# 11   千葉県   24.04   22.28  85.27  79.80 100.54  93.06
# ..   ...     ...     ...    ...    ...    ...    ...
# 35   徳島県   24.13   22.59  85.46  79.91 101.51  93.94
# 36   香川県   23.98   22.47  85.15  79.70 102.37  95.39
# 37   愛媛県   24.05   22.44  84.86  79.54 101.31  92.56
# 38   高知県   23.98   22.51  85.29  80.48 104.22  96.11
# 39   福岡県   23.85   22.11  85.09  80.07 101.97  93.93
# 40   佐賀県   23.74   22.36  84.93  80.66 101.21  93.00
# 41   長崎県   23.90   22.47  84.88  80.32 101.92  94.32
# 42   熊本県   23.95   22.38  85.36  80.77 103.24  95.11
# 43   大分県   23.98   22.51  84.89  80.67 101.84  94.30
# 44   宮崎県   23.99   22.62  85.02  81.11 101.58  93.89
# 45  鹿児島県   24.04   22.71  85.05  80.77 103.77  95.74
# 46   沖縄県   25.02   23.49  87.26  82.32 102.91  94.70
#
# [47 rows x 7 columns]

# %%
print(health_df_trans.to_csv(), file=open('人均烟税.csv', 'w'))
